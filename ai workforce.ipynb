# %%
import pandas as pd
import matplotlib.pyplot as py

# %%
da=pd.read_csv('ai_workforce.csv')
da
# Out:
#        record_id        country iso3_code         region         income_group  \
# 0              1  United States       USA  North America          High Income
# 1              2  United States       USA  North America          High Income
# 2              3  United States       USA  North America          High Income
# 3              4  United States       USA  North America          High Income
# 4              5  United States       USA  North America          High Income
# ...          ...            ...       ...            ...                  ...
# 20795      20796         Zambia       ZMB         Africa  Lower Middle Income
# 20796      20797         Zambia       ZMB         Africa  Lower Middle Income
# 20797      20798         Zambia       ZMB         Africa  Lower Middle Income
# 20798      20799         Zambia       ZMB         Africa  Lower Middle Income
# 20799      20800         Zambia       ZMB         Africa  Lower Middle Income
#
# ...

# %%
da.columns
# Out:
# Index(['record_id', 'country', 'iso3_code', 'region', 'income_group', 'year',
#        'quarter', 'quarter_label', 'industry_sector',
#        'sector_automation_risk_score', 'gdp_per_capita_usd',
#        'ai_adoption_index', 'pct_sector_workforce_displaced',
#        'pct_sector_workforce_new_roles_created', 'net_workforce_change_pct',
#        'ai_cited_layoff_announcements', 'ai_skill_wage_premium_pct',
#        'pct_workforce_female', 'pct_displaced_roles_female',
#        'reskilling_programs_count', 'govt_ai_policy_score_1_to_10',
#        'ai_tool_adoption_pct', 'data_source_notes'],
#       dtype='str')

# %%
da.shape
# Out:
# (20800, 23)

# %%
da.info
# Out:
# <bound method DataFrame.info of        record_id        country iso3_code         region         income_group  \
# 0              1  United States       USA  North America          High Income
# 1              2  United States       USA  North America          High Income
# 2              3  United States       USA  North America          High Income
# 3              4  United States       USA  North America          High Income
# 4              5  United States       USA  North America          High Income
# ...          ...            ...       ...            ...                  ...
# 20795      20796         Zambia       ZMB         Africa  Lower Middle Income
# 20796      20797         Zambia       ZMB         Africa  Lower Middle Income
# 20797      20798         Zambia       ZMB         Africa  Lower Middle Income
# 20798      20799         Zambia       ZMB         Africa  Lower Middle Income
# 20799      20800         Zambia       ZMB         Africa  Lower Middle Income
#
# ...

# %%
da.isnull().sum()
# Out:
# record_id                                 0
# country                                   0
# iso3_code                                 0
# region                                    0
# income_group                              0
# year                                      0
# quarter                                   0
# quarter_label                             0
# industry_sector                           0
# sector_automation_risk_score              0
# gdp_per_capita_usd                        0
# ai_adoption_index                         0
# pct_sector_workforce_displaced            0
# pct_sector_workforce_new_roles_created    0
# net_workforce_change_pct                  0
# ai_cited_layoff_announcements             0
# ai_skill_wage_premium_pct                 0
# pct_workforce_female                      0
# pct_displaced_roles_female                0
# reskilling_programs_count                 0
# govt_ai_policy_score_1_to_10              0
# ...

# %%
da.drop(columns=['country','iso3_code','region','year','quarter_label','industry_sector','record_id','income_group','quarter','data_source_notes'],inplace=True)
da
# Out:
#        sector_automation_risk_score  gdp_per_capita_usd  ai_adoption_index  \
# 0                             0.382               63514              0.830
# 1                             0.608               63514              0.817
# 2                             0.198               63514              0.816
# 3                             0.720               63514              0.818
# 4                             0.676               63514              0.828
# ...                             ...                 ...                ...
# 20795                         0.308                1467              0.703
# 20796                         0.675                1467              0.711
# 20797                         0.516                1467              0.709
# 20798                         0.801                1467              0.702
# 20799                         0.440                1467              0.718
#
# ...

# %%
py.hist(da['sector_automation_risk_score'])
py.show()

# %%
da['gdp_per_capita_usd'].value_counts().plot(kind='hist')
py.show()
da['pct_sector_workforce_displaced'].value_counts().plot(kind='hist')
py.show()

# %%
da['ai_adoption_index'].value_counts().plot(kind='hist')
py.show()
da['pct_sector_workforce_displaced'].value_counts().plot(kind='hist')
py.show()
da['pct_sector_workforce_new_roles_created'].value_counts().plot(kind='hist')
py.show()
da['net_workforce_change_pct'].value_counts().plot(kind='hist')
py.show()
da['ai_cited_layoff_announcements'].value_counts().plot(kind='hist')
py.show()
da['ai_skill_wage_premium_pct'].value_counts().plot(kind='hist')
py.show()

# %%
da['pct_workforce_female'].value_counts().plot(kind='pie')
py.show()
da['pct_displaced_roles_female'].value_counts().plot(kind='hist')
py.show()
da['reskilling_programs_count'].value_counts().plot(kind='hist')
py.show()
da['govt_ai_policy_score_1_to_10'].value_counts().plot(kind='hist')
py.show()
da['ai_tool_adoption_pct'].value_counts().plot(kind='hist')
py.show()
